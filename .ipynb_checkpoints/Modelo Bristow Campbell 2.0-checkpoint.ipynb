# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows',40000)
pd.set_option('display.max_columns',2200)

# %%
grupo1=pd.read_excel(r'C:\Users\Katia Suely\Desktop\GrupoAnual1.xlsx')
grupo1
# Out:
#      Unnamed: 0        KT   Δt grupos
# 0    2014-01-01  0.694885  4.3      C
# 1    2014-01-02  0.650535  5.2      C
# 2    2014-01-03  0.677482  4.7      C
# 3    2014-01-04  0.494963  6.0      B
# 4    2014-01-05  0.475678  6.0      B
# 5    2014-01-06  0.548233  5.7      B
# 6    2014-01-07  0.341513  3.7      A
# 7    2014-01-08  0.650903  6.5      C
# 8    2014-01-09  0.586358  6.5      B
# 9    2014-01-10  0.584685  5.0      B
# 10   2014-01-11  0.642389  6.2      C
# 11   2014-01-12  0.695101  5.1      C
# 12   2014-01-13  0.505048  5.7      B
# 13   2014-01-14  0.503992  6.5      B
# 14   2014-01-15  0.574299  4.7      B
# 15   2014-01-16  0.672965  5.3      C
# 16   2014-01-17  0.658560  4.4      C
# 17   2014-01-18  0.638952  4.1      C
# 18   2014-01-19  0.592666  4.6      B
# 19   2014-01-20  0.607381  4.2      C
# 20   2014-01-21  0.611321  5.0      C
# 21   2014-01-22  0.669603  4.6      C
# 22   2014-01-23  0.579095  6.2      B
# 23   2014-01-24  0.675592  4.2      C
# ...

# %%
grupo2=pd.read_excel(r'C:\Users\Katia Suely\Desktop\GrupoAnual2.xlsx')
grupo2
# Out:
#      Unnamed: 0        KT    Δt grupos
# 0    2014-02-01  0.673114   4.5      C
# 1    2014-02-02  0.701520   5.0      C
# 2    2014-02-03  0.378825   5.8      A
# 3    2014-02-04  0.668197   6.3      C
# 4    2014-02-05  0.718531   6.4      C
# 5    2014-02-06  0.691268   6.0      C
# 6    2014-02-07  0.613101   6.9      C
# 7    2014-02-08  0.689066   4.4      C
# 8    2014-02-09  0.690190   4.9      C
# 9    2014-02-10  0.712756   5.6      C
# 10   2014-02-11  0.606988   6.4      C
# 11   2014-02-12  0.643707   6.0      C
# 12   2014-02-13  0.692092   5.8      C
# 13   2014-02-14  0.598278   4.2      B
# 14   2014-02-15  0.477556   5.3      B
# 15   2014-02-16  0.439931   5.3      B
# 16   2014-02-17  0.456973   6.3      B
# 17   2014-02-18  0.553955   7.5      B
# 18   2014-02-19  0.569402   6.7      B
# 19   2014-02-20  0.538184   6.0      B
# 20   2014-02-21  0.406785   4.5      B
# 21   2014-02-22  0.667725   4.7      C
# 22   2014-02-23  0.522359   6.8      B
# ...

# %%
def KTBC(Δt,A,B,C):
    return A*(1-np.exp(-B*Δt**C))

# %%
g = [0.75,0.7,2.4]

# %matplotlib inline

n1= len(grupo1.KT)
y1= np.empty(n1)

n2= len(grupo2.KT)
y2= np.empty(n2)


for i in range (n1):
    y1[i]=KTBC(grupo1.KT[i],g[0],g[1],g[2])

for i in range (n2):
    y2[i]=KTBC(grupo2.KT[i],g[0],g[1],g[2])   

plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.scatter(grupo2.Δt,y2,color='y')

plt.show()

# %%
from scipy.optimize import curve_fit
c1,cov1 = curve_fit(KTBC,grupo1.Δt.values,grupo1.KT.values,g)
c2,cov2 = curve_fit(KTBC,grupo2.Δt.values,grupo2.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(grupo1.Δt[i],c1[0],c1[1],c1[2])
    
for i in range (n2):
    y2[i]=KTBC(grupo2.Δt[i],c2[0],c2[1],c2[2])
    
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.scatter(grupo2.Δt,y2,color='y')
plt.show()
# Out:
# <ipython-input-4-2da2e0ee181f>:2: RuntimeWarning: divide by zero encountered in power
#   return A*(1-np.exp(-B*Δt**C))

# %%
c1
# Out:
# array([6.33760494e-01, 2.69565523e-05, 8.49607880e+00])

# %%
c2
# Out:
# array([0.61823869, 0.09953205, 1.90957548])

# %%
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.2)
#plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.2)
plt.scatter(grupo1.Δt,y1,color='r')
#plt.scatter(grupo2.Δt,y2,color='b')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(grupo1.KT,y1))
print('R^2: ', r2_score(grupo2.KT,y2))
# Out:
# R^2:  0.17957183539425503
# R^2:  0.2918465978426438

# %%
grupo1.KT.describe()
# Out:
# count    1020.000000
# mean        0.625559
# std         0.097691
# min         0.021331
# 25%         0.596545
# 50%         0.657448
# 75%         0.688450
# max         0.746732
# Name: KT, dtype: float64

# %%
pd.DataFrame(y1).describe()
# Out:
#                  0
# count  1020.000000
# mean      0.625437
# std       0.043202
# min       0.039767
# 25%       0.633525
# 50%       0.633760
# 75%       0.633760
# max       0.633760

# %%
y1=pd.DataFrame(y1)
y1.index=grupo1.index

# %%
x=pd.DataFrame(grupo1.KT)
x.describe()
# Out:
#                 KT
# count  1020.000000
# mean      0.625559
# std       0.097691
# min       0.021331
# 25%       0.596545
# 50%       0.657448
# 75%       0.688450
# max       0.746732

# %%
y1.describe()
# Out:
#                  0
# count  1020.000000
# mean      0.625437
# std       0.043202
# min       0.039767
# 25%       0.633525
# 50%       0.633760
# 75%       0.633760
# max       0.633760

# %%
y1-x
# Out:
#        0  KT
# 0    NaN NaN
# 1    NaN NaN
# 2    NaN NaN
# 3    NaN NaN
# 4    NaN NaN
# 5    NaN NaN
# 6    NaN NaN
# 7    NaN NaN
# 8    NaN NaN
# 9    NaN NaN
# 10   NaN NaN
# 11   NaN NaN
# 12   NaN NaN
# 13   NaN NaN
# 14   NaN NaN
# 15   NaN NaN
# 16   NaN NaN
# 17   NaN NaN
# 18   NaN NaN
# 19   NaN NaN
# 20   NaN NaN
# 21   NaN NaN
# 22   NaN NaN
# 23   NaN NaN
# 24   NaN NaN
# 25   NaN NaN
# 26   NaN NaN
# 27   NaN NaN
# 28   NaN NaN
# 29   NaN NaN
# 30   NaN NaN
# 31   NaN NaN
# 32   NaN NaN
# 33   NaN NaN
# 34   NaN NaN
# 35   NaN NaN
# 36   NaN NaN
# 37   NaN NaN
# 38   NaN NaN
# 39   NaN NaN
# 40   NaN NaN
# 41   NaN NaN
# 42   NaN NaN
# 43   NaN NaN
# 44   NaN NaN
# 45   NaN NaN
# 46   NaN NaN
# 47   NaN NaN
# 48   NaN NaN
# 49   NaN NaN
# 50   NaN NaN
# 51   NaN NaN
# 52   NaN NaN
# 53   NaN NaN
# 54   NaN NaN
# 55   NaN NaN
# 56   NaN NaN
# 57   NaN NaN
# 58   NaN NaN
# 59   NaN NaN
# 60   NaN NaN
# 61   NaN NaN
# 62   NaN NaN
# 63   NaN NaN
# 64   NaN NaN
# ...

# %%
plt.scatter(x.index,x,alpha=0.2)
plt.scatter(y1.index,y1,alpha=0.2)
plt.show()

# %%
grupo1['KTestimado']=KTBC(grupo1.Δt,c1[0],c1[1],c1[2])
grupo1
# Out:
#      Unnamed: 0        KT   Δt grupos  KTestimado
# 0    2014-01-01  0.694885  4.3      C    0.632804
# 1    2014-01-02  0.650535  5.2      C    0.633760
# 2    2014-01-03  0.677482  4.7      C    0.633760
# 3    2014-01-04  0.494963  6.0      B    0.633760
# 4    2014-01-05  0.475678  6.0      B    0.633760
# 5    2014-01-06  0.548233  5.7      B    0.633760
# 6    2014-01-07  0.341513  3.7      A    0.530247
# 7    2014-01-08  0.650903  6.5      C    0.633760
# 8    2014-01-09  0.586358  6.5      B    0.633760
# 9    2014-01-10  0.584685  5.0      B    0.633760
# 10   2014-01-11  0.642389  6.2      C    0.633760
# 11   2014-01-12  0.695101  5.1      C    0.633760
# 12   2014-01-13  0.505048  5.7      B    0.633760
# 13   2014-01-14  0.503992  6.5      B    0.633760
# 14   2014-01-15  0.574299  4.7      B    0.633760
# 15   2014-01-16  0.672965  5.3      C    0.633760
# 16   2014-01-17  0.658560  4.4      C    0.633525
# 17   2014-01-18  0.638952  4.1      C    0.625452
# ...

# %%
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.2)
#plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.2)
plt.scatter(grupo1.Δt,y1,color='r')
#plt.scatter(grupo2.Δt,y2,color='b')
plt.show()

# %%
KTBC(4.3,c1[0],c1[1],c1[2])
# Out:
# 0.6328040873638667
