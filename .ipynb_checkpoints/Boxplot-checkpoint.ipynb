# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 8500)

df=[]
df=pd.DataFrame(df)

nome_meses=['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']

for y in range (4,9): 
    for m in nome_meses:
        a=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Planilhas do programa\201{}\201{}{}.xlsx'.format(y,y,m))
        df=df.append(a)

# %%
df.set_index('Unnamed: 0',inplace=True)

# %%
sns.set(style="darkgrid")
plt.gcf().set_size_inches(300, 10)
sns.cubehelix_palette(start=.5, rot=-.6, as_cmap=True)
chart=sns.boxplot(x=df.index.strftime('%m--%H:%M'),y=df['SolarRad'], data=df,palette="Spectral")
chart.set_xticklabels(chart.get_xticklabels(), rotation=65)

plt.show()

# %%
Data=[]
Data=pd.DataFrame(Data)
for y in range (4,9): 
    for m in ['jan','fev','mar','abr','mai','jun','jul','ago','set','out','nov','dez']:
        a=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Planilhas do programa\201{}\201{}{}.xlsx'.format(y,y,m))
        Data=Data.append(a)
        
Data.set_index('Unnamed: 0',inplace=True)

# %%
filt=(Data.index.strftime("%H:%M:%S") >= '09:40:00') & (Data.index.strftime("%H:%M:%S") <= '13:40:00') & (Data.SolarRad<=200) 
Data.loc[filt]
# Out:
#                      SolarRad      Rain  TempOut FilledData
# Unnamed: 0
# 2014-01-25 09:40:00     153.0   14000.0  25200.0      Lavat
# 2014-01-30 09:40:00     173.0       0.6  24500.0      Lavat
# 2014-01-30 09:50:00     184.0       0.4  24600.0      Lavat
# 2014-01-30 10:30:00     160.0       0.0  25200.0      Lavat
# 2014-01-30 10:50:00     136.0       0.0  25100.0      Lavat
# 2014-01-30 11:00:00     103.0       0.2  24700.0      Lavat
# 2014-01-30 11:10:00     106.0       0.0  24800.0      Lavat
# 2014-01-30 11:20:00      99.0       0.0  24800.0      Lavat
# 2014-01-30 11:30:00      90.0       0.4  24500.0      Lavat
# 2014-01-30 11:40:00     104.0       0.6  24400.0      Lavat
# 2014-01-30 11:50:00      80.0       0.0  24500.0      Lavat
# 2014-01-30 12:00:00      69.0       0.4  24400.0      Lavat
# 2014-01-30 12:10:00      68.0       0.4  24000.0      Lavat
# 2014-01-30 12:20:00      87.0       0.2  24000.0      Lavat
# ...
