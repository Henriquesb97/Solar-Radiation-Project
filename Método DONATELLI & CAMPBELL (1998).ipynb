# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
pd.set_option('display.max_rows',52560)

# %% [markdown]
# ## Valores de Δt Diários

# %%
deltaT=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Valores de Δt.xlsx')
deltaT.index=deltaT['Unnamed: 0']
deltaT=deltaT.drop(['Unnamed: 0'],axis=1)
deltaT
# Out:
#             Tminday  Tmaxday    Δt
# Unnamed: 0
# 14-01-01       25.9     30.2   4.3
# 14-01-02       25.2     30.4   5.2
# 14-01-03       25.6     30.3   4.7
# 14-01-04       24.2     30.2   6.0
# 14-01-05       24.4     30.4   6.0
# 14-01-06       24.6     30.3   5.7
# 14-01-07       24.9     28.6   3.7
# 14-01-08       23.8     30.3   6.5
# 14-01-09       23.4     29.9   6.5
# 14-01-10       24.8     29.8   5.0
# 14-01-11       24.3     30.5   6.2
# 14-01-12       24.9     30.0   5.1
# 14-01-13       24.3     30.0   5.7
# 14-01-14       24.2     30.7   6.5
# 14-01-15       25.6     30.3   4.7
# 14-01-16       25.1     30.4   5.3
# 14-01-17       26.2     30.6   4.4
# 14-01-18       26.2     30.3   4.1
# 14-01-19       25.8     30.4   4.6
# 14-01-20       26.0     30.2   4.2
# 14-01-21       25.6     30.6   5.0
# 14-01-22       26.3     30.9   4.6
# 14-01-23       24.7     30.9   6.2
# 14-01-24       26.2     30.4   4.2
# 14-01-25       23.3     29.9   6.6
# ...

# %% [markdown]
# ## KT's Diários

# %%
KTs=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Valores de KT diario.xlsx')
KTs.index=KTs['Unnamed: 0']
KTs=KTs.drop(['Unnamed: 0'],axis=1)
KTs
# Out:
#                       H            Ho        KT
# Unnamed: 0
# 2014-01-01  7339.333333  10561.938788  0.694885
# 2014-01-02  6873.166667  10565.398497  0.650535
# 2014-01-03  7160.333333  10569.036988  0.677482
# 2014-01-04  5233.166667  10572.847367  0.494963
# 2014-01-05  5031.166667  10576.822254  0.475678
# 2014-01-06  5800.833333  10580.953800  0.548233
# 2014-01-07  3615.000000  10585.233688  0.341513
# 2014-01-08  6892.833333  10589.653150  0.650903
# 2014-01-09  6212.000000  10594.202976  0.586358
# 2014-01-10  6197.000000  10598.873526  0.584685
# 2014-01-11  6811.666667  10603.654743  0.642389
# 2014-01-12  7374.000000  10608.536166  0.695101
# 2014-01-13  5360.333333  10613.506946  0.505048
# 2014-01-14  5351.666667  10618.555856  0.503992
# 2014-01-15  6101.166667  10623.671309  0.574299
# 2014-01-16  7152.833333  10628.841374  0.672965
# 2014-01-17  7003.166667  10634.053791  0.658560
# 2014-01-18  6798.000000  10639.295987  0.638952
# ...

# %%
metodo=[]
metodo=pd.DataFrame(metodo)
metodo['KT']=KTs.KT
deltaT.index=KTs.index
metodo['Δt']=deltaT.Δt

# %%
filt=(deltaT.Tmaxday>45) 
metodo.loc[filt]
metodo.Δt.replace(metodo.Δt.loc[filt],np.nan,inplace=True)
metodo=metodo.dropna()
metodo.index = pd.to_datetime(metodo.index, format = '%Y-%m-%d')
metodo
# Out:
#                   KT    Δt
# Unnamed: 0
# 2014-01-01  0.694885   4.3
# 2014-01-02  0.650535   5.2
# 2014-01-03  0.677482   4.7
# 2014-01-04  0.494963   6.0
# 2014-01-05  0.475678   6.0
# 2014-01-06  0.548233   5.7
# 2014-01-07  0.341513   3.7
# 2014-01-08  0.650903   6.5
# 2014-01-09  0.586358   6.5
# 2014-01-10  0.584685   5.0
# 2014-01-11  0.642389   6.2
# 2014-01-12  0.695101   5.1
# 2014-01-13  0.505048   5.7
# 2014-01-14  0.503992   6.5
# 2014-01-15  0.574299   4.7
# 2014-01-16  0.672965   5.3
# 2014-01-17  0.658560   4.4
# 2014-01-18  0.638952   4.1
# 2014-01-19  0.592666   4.6
# 2014-01-20  0.607381   4.2
# 2014-01-21  0.611321   5.0
# 2014-01-22  0.669603   4.6
# 2014-01-23  0.579095   6.2
# 2014-01-24  0.675592   4.2
# 2014-01-25  0.402206   6.6
# 2014-01-26  0.702060   5.6
# 2014-01-27  0.593867   6.1
# 2014-01-28  0.690448   4.4
# 2014-01-29  0.581623   6.7
# 2014-01-30  0.113073   2.5
# 2014-01-31  0.712399   6.8
# 2014-02-01  0.673114   4.5
# 2014-02-02  0.701520   5.0
# ...

# %%
deltaTmédio=metodo.Δt.groupby(metodo.index.strftime('%m')).mean()
metodo['Δt Médio']= 0
metodo
# Out:
#                   KT    Δt  Δt Médio
# Unnamed: 0
# 2014-01-01  0.694885   4.3         0
# 2014-01-02  0.650535   5.2         0
# 2014-01-03  0.677482   4.7         0
# 2014-01-04  0.494963   6.0         0
# 2014-01-05  0.475678   6.0         0
# 2014-01-06  0.548233   5.7         0
# 2014-01-07  0.341513   3.7         0
# 2014-01-08  0.650903   6.5         0
# 2014-01-09  0.586358   6.5         0
# 2014-01-10  0.584685   5.0         0
# 2014-01-11  0.642389   6.2         0
# 2014-01-12  0.695101   5.1         0
# 2014-01-13  0.505048   5.7         0
# 2014-01-14  0.503992   6.5         0
# 2014-01-15  0.574299   4.7         0
# 2014-01-16  0.672965   5.3         0
# 2014-01-17  0.658560   4.4         0
# 2014-01-18  0.638952   4.1         0
# 2014-01-19  0.592666   4.6         0
# 2014-01-20  0.607381   4.2         0
# 2014-01-21  0.611321   5.0         0
# 2014-01-22  0.669603   4.6         0
# 2014-01-23  0.579095   6.2         0
# 2014-01-24  0.675592   4.2         0
# ...

# %%
deltaTmédio
# Out:
# Unnamed: 0
# 01    5.117204
# 02    5.435542
# 03    5.810215
# 04    5.713889
# 05    5.883333
# 06    5.632184
# 07    5.730978
# 08    6.240491
# 09    5.220000
# 10    5.025904
# 11    4.716111
# 12    4.808571
# Name: Δt, dtype: float64

# %%
metodo['Δt Médio'][metodo.index.strftime('%m')=='01']=deltaTmédio['01']
metodo['Δt Médio'][metodo.index.strftime('%m')=='02']=deltaTmédio['02']
metodo['Δt Médio'][metodo.index.strftime('%m')=='03']=deltaTmédio['03']
metodo['Δt Médio'][metodo.index.strftime('%m')=='04']=deltaTmédio['04']
metodo['Δt Médio'][metodo.index.strftime('%m')=='05']=deltaTmédio['05']
metodo['Δt Médio'][metodo.index.strftime('%m')=='06']=deltaTmédio['06']
metodo['Δt Médio'][metodo.index.strftime('%m')=='07']=deltaTmédio['07']
metodo['Δt Médio'][metodo.index.strftime('%m')=='08']=deltaTmédio['08']
metodo['Δt Médio'][metodo.index.strftime('%m')=='09']=deltaTmédio['09']
metodo['Δt Médio'][metodo.index.strftime('%m')=='10']=deltaTmédio['10']
metodo['Δt Médio'][metodo.index.strftime('%m')=='11']=deltaTmédio['11']
metodo['Δt Médio'][metodo.index.strftime('%m')=='12']=deltaTmédio['12']
# Out:
# <ipython-input-11-57e011790346>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metodo['Δt Médio'][metodo.index.strftime('%m')=='01']=deltaTmédio['01']

# %%
metodo
# Out:
#                   KT    Δt  Δt Médio
# Unnamed: 0
# 2014-01-01  0.694885   4.3  5.117204
# 2014-01-02  0.650535   5.2  5.117204
# 2014-01-03  0.677482   4.7  5.117204
# 2014-01-04  0.494963   6.0  5.117204
# 2014-01-05  0.475678   6.0  5.117204
# 2014-01-06  0.548233   5.7  5.117204
# 2014-01-07  0.341513   3.7  5.117204
# 2014-01-08  0.650903   6.5  5.117204
# 2014-01-09  0.586358   6.5  5.117204
# 2014-01-10  0.584685   5.0  5.117204
# 2014-01-11  0.642389   6.2  5.117204
# 2014-01-12  0.695101   5.1  5.117204
# 2014-01-13  0.505048   5.7  5.117204
# 2014-01-14  0.503992   6.5  5.117204
# 2014-01-15  0.574299   4.7  5.117204
# 2014-01-16  0.672965   5.3  5.117204
# 2014-01-17  0.658560   4.4  5.117204
# 2014-01-18  0.638952   4.1  5.117204
# 2014-01-19  0.592666   4.6  5.117204
# 2014-01-20  0.607381   4.2  5.117204
# 2014-01-21  0.611321   5.0  5.117204
# 2014-01-22  0.669603   4.6  5.117204
# 2014-01-23  0.579095   6.2  5.117204
# 2014-01-24  0.675592   4.2  5.117204
# ...

# %%
def KTDC(J,A,B,C):
    Δt,Δtm = J
    return A*(1-np.exp(-B*((Δt**C)/Δtm)))

# %%
Δt=metodo['Δt'].values
Δtm=metodo['Δt Médio'].values
A,B,C = [0.80,0.07,2.4]

y=KTDC((Δt,Δtm),A,B,C)

plt.scatter(metodo['Δt'],metodo['KT'])
plt.scatter(metodo['Δt'],y)

# %%
import numpy as np
from scipy.optimize import curve_fit

def func(X, a, b, c):
    x,y = X
    return np.log(a) + b*np.log(x) + c*np.log(y)

# some artificially noisy data to fit
x = np.linspace(0.1,1.1,101)
y = np.linspace(1.,2., 101)
a, b, c = 10., 4., 6.
z = func((x,y), a, b, c) * 1 + np.random.random(101) / 100

# initial guesses for a,b,c:
p0 = 8., 2., 7.
print curve_fit(func, (x,y), z, p0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-50f46e6e2c89> in <module>
#       2 g=0.80,0.07,2.4
#       3
# ----> 4 c,cov = curve_fit(KTDC,(Δt.values,Δtm.values),g)
#       5
#       6 y=KTDC((Δt,Δtm),c[0],c[1],c[2])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'

# %%
a, b, c = 10., 4., 6.
z = KTDC((Δt,Δtm), A, B, C) 

print curve_fit(ktbc, (Δt,Δtm), z, G)
# Out:
#   File "<ipython-input-22-6ba12cbe20bf>", line 4
#     print curve_fit(ktbc, (Δt,Δtm), z, G)
#           ^
# SyntaxError: invalid syntax

# %%
def KTDC(Z,A,B,C):
    metodo.Δt,metodo['Δt Médio']=Z
    return A*(1-np.exp(-B*((Δt**C)/Δtm)))

g = [0.80,0.07,2.4]


y=KTDC((metodo.Δt,metodo['Δt Médio']),g[0],g[1],g[2])

plt.scatter(metodo['Δt'],metodo['KT'],s=50,alpha=0.07)
plt.scatter(metodo['Δt'],y)
plt.show()

# %%
g = [0.80,0.07,2.4]

# %matplotlib inline
y=KTDC((metodo.Δt,metodo['Δt Médio']),g[0],g[1],g[2])

plt.scatter(metodo['Δt'],metodo['KT'],s=50,alpha=0.07)
plt.scatter(metodo['Δt'],y)
plt.show()

# %%
y

# %%
metodo['Δt']

# %%
from scipy.optimize import curve_fit
c,cov = curve_fit(KTDC,metodo['Δt'],metodo['KT'].values,g)

for i in range (n):
    y[i]=KTDC((metodo['Δt'][i],metodo['Δt Médio'][i]),c[0],c[1],c[2])

plt.scatter(metodo['Δt'],metodo['KT'],s=50,alpha=0.07)
plt.scatter(metodo['Δt'],y)

# %%
pd.DataFrame(y)
