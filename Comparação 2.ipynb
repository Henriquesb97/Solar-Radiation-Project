# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 8500)

# %%
y=8
Dados_lavat=[]
Dados_lavat=pd.DataFrame(Dados_lavat)

nome_meses=['abr','mai','jun','jul','ago','set','out','nov','dez']


for m in nome_meses:
    a=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Planilhas do programa\201{}\201{}{}.xlsx'.format(y,y,m))
    Dados_lavat=Dados_lavat.append(a)
Dados_lavat.set_index('Unnamed: 0',inplace=True)

# %%
y=8
Dados_usina=[]
Dados_usina=pd.DataFrame(Dados_usina)
 
for m in ['Abril','Maio','Junho','Julho','Agosto','Setembro','Outubro','Novembro','Dezembro']:
    b=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Dados usina\{} 201{} ESI.xlsx'.format(m,y))
    Dados_usina=Dados_usina.append(b)
        
Dados_usina.set_index('DataRange',inplace=True)
Dados_usina.replace('--',np.nan,inplace=True)
Dados_usina['value']=Dados_usina.value.apply(float)

# %%
Dados_usina
# Out:
#                      value 2018-08-01 0:00:00,--  Unnamed: 1  Unnamed: 2  \
# DataRange
# 2018-04-01 00:00:00    NaN                   NaN         NaN         NaN
# 2018-04-01 00:15:00    NaN                   NaN         NaN         NaN
# 2018-04-01 00:30:00    NaN                   NaN         NaN         NaN
# 2018-04-01 00:45:00    NaN                   NaN         NaN         NaN
# 2018-04-01 01:00:00    NaN                   NaN         NaN         NaN
# ...                    ...                   ...         ...         ...
# 2018-12-31 22:45:00    NaN                   NaN         NaN         NaN
# 2018-12-31 23:00:00    NaN                   NaN         NaN         NaN
# 2018-12-31 23:15:00    NaN                   NaN         NaN         NaN
# 2018-12-31 23:30:00    NaN                   NaN         NaN         NaN
# 2018-12-31 23:45:00    NaN                   NaN         NaN         NaN
#
#                      Unnamed: 3 2018-08-01 00:00:00  --
# DataRange
# ...

# %%
sns.set(style="darkgrid")
plt.gcf().set_size_inches(500, 10)
plt.plot(Dados_usina.index,Dados_usina['value'],'red',Dados_lavat.index,Dados_lavat['SolarRad'],'blue')
