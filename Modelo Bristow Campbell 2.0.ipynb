# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows',40000)
pd.set_option('display.max_columns',2200)

# %%
Hs=pd.read_excel(r'C:\Users\Katia Suely\Desktop\Valores de KT diario.xlsx')
Hs.index=Hs['Unnamed: 0']
Hs=Hs.drop(['Unnamed: 0'],axis=1)
Hs.index=pd.to_datetime(Hs.index, format = '%Y-%m-%d')
Hs=(Hs*3600)/10**6    # Para transformar de Watts*h/m² para MJ por m² por dia
Hs
# Out:
#                   H         Ho        KT
# Unnamed: 0
# 2014-01-01  26.4216  38.022980  0.002502
# 2014-01-02  24.7434  38.035435  0.002342
# 2014-01-03  25.7772  38.048533  0.002439
# 2014-01-04  18.8394  38.062251  0.001782
# 2014-01-05  18.1122  38.076560  0.001712
# 2014-01-06  20.8830  38.091434  0.001974
# 2014-01-07  13.0140  38.106841  0.001229
# 2014-01-08  24.8142  38.122751  0.002343
# 2014-01-09  22.3632  38.139131  0.002111
# 2014-01-10  22.3092  38.155945  0.002105
# 2014-01-11  24.5220  38.173157  0.002313
# 2014-01-12  26.5464  38.190730  0.002502
# 2014-01-13  19.2972  38.208625  0.001818
# 2014-01-14  19.2660  38.226801  0.001814
# 2014-01-15  21.9642  38.245217  0.002067
# 2014-01-16  25.7502  38.263829  0.002423
# 2014-01-17  25.2114  38.282594  0.002371
# 2014-01-18  24.4728  38.301466  0.002300
# 2014-01-19  22.7112  38.320398  0.002134
# 2014-01-20  23.2866  38.339345  0.002187
# 2014-01-21  23.4492  38.358256  0.002201
# ...

# %%
grupo1=pd.read_excel(r'C:\Users\Katia Suely\Desktop\GrupoAnual1.xlsx')
grupo1.index=grupo1['Unnamed: 0']
grupo1
# Out:
#            Unnamed: 0        KT   Δt grupos
# Unnamed: 0
# 2014-01-01 2014-01-01  0.694885  4.3      C
# 2014-01-02 2014-01-02  0.650535  5.2      C
# 2014-01-03 2014-01-03  0.677482  4.7      C
# 2014-01-04 2014-01-04  0.494963  6.0      B
# 2014-01-05 2014-01-05  0.475678  6.0      B
# 2014-01-06 2014-01-06  0.548233  5.7      B
# 2014-01-07 2014-01-07  0.341513  3.7      A
# 2014-01-08 2014-01-08  0.650903  6.5      C
# 2014-01-09 2014-01-09  0.586358  6.5      B
# 2014-01-10 2014-01-10  0.584685  5.0      B
# 2014-01-11 2014-01-11  0.642389  6.2      C
# 2014-01-12 2014-01-12  0.695101  5.1      C
# 2014-01-13 2014-01-13  0.505048  5.7      B
# 2014-01-14 2014-01-14  0.503992  6.5      B
# 2014-01-15 2014-01-15  0.574299  4.7      B
# 2014-01-16 2014-01-16  0.672965  5.3      C
# 2014-01-17 2014-01-17  0.658560  4.4      C
# 2014-01-18 2014-01-18  0.638952  4.1      C
# 2014-01-19 2014-01-19  0.592666  4.6      B
# 2014-01-20 2014-01-20  0.607381  4.2      C
# ...

# %%
grupo2=pd.read_excel(r'C:\Users\Katia Suely\Desktop\GrupoAnual2.xlsx')
grupo2.index=grupo2['Unnamed: 0']
grupo2
# Out:
#            Unnamed: 0        KT    Δt grupos
# Unnamed: 0
# 2014-02-01 2014-02-01  0.673114   4.5      C
# 2014-02-02 2014-02-02  0.701520   5.0      C
# 2014-02-03 2014-02-03  0.378825   5.8      A
# 2014-02-04 2014-02-04  0.668197   6.3      C
# 2014-02-05 2014-02-05  0.718531   6.4      C
# 2014-02-06 2014-02-06  0.691268   6.0      C
# 2014-02-07 2014-02-07  0.613101   6.9      C
# 2014-02-08 2014-02-08  0.689066   4.4      C
# 2014-02-09 2014-02-09  0.690190   4.9      C
# 2014-02-10 2014-02-10  0.712756   5.6      C
# 2014-02-11 2014-02-11  0.606988   6.4      C
# 2014-02-12 2014-02-12  0.643707   6.0      C
# 2014-02-13 2014-02-13  0.692092   5.8      C
# 2014-02-14 2014-02-14  0.598278   4.2      B
# 2014-02-15 2014-02-15  0.477556   5.3      B
# 2014-02-16 2014-02-16  0.439931   5.3      B
# 2014-02-17 2014-02-17  0.456973   6.3      B
# 2014-02-18 2014-02-18  0.553955   7.5      B
# 2014-02-19 2014-02-19  0.569402   6.7      B
# 2014-02-20 2014-02-20  0.538184   6.0      B
# ...

# %%
grupo1e2=pd.concat([grupo1,grupo2]).sort_index()

# %%
grupo1e2.to_excel(r'C:\Users\Katia Suely\Desktop\Planilhas do programa\2016dez.xlsx')

# %%
jans=grupo1e2[pd.to_datetime(grupo1e2.index).month == 1]
fevs=grupo1e2[pd.to_datetime(grupo1e2.index).month == 2]
mars=grupo1e2[pd.to_datetime(grupo1e2.index).month == 3]
agos=grupo1e2[pd.to_datetime(grupo1e2.index).month == 8]
sets=grupo1e2[pd.to_datetime(grupo1e2.index).month == 9]
outs=grupo1e2[pd.to_datetime(grupo1e2.index).month == 10]
novs=grupo1e2[pd.to_datetime(grupo1e2.index).month == 11]
dezs=grupo1e2[pd.to_datetime(grupo1e2.index).month == 12]
grupo1=pd.concat([jans,fevs,mars,agos,sets,outs,novs,dezs]).sort_index()

# %%
abrs=grupo1e2[pd.to_datetime(grupo1e2.index).month == 4]
mais=grupo1e2[pd.to_datetime(grupo1e2.index).month == 5]
juns=grupo1e2[pd.to_datetime(grupo1e2.index).month == 6]
juls=grupo1e2[pd.to_datetime(grupo1e2.index).month == 7]
grupo2=pd.concat([abrs,mais,juns,juls]).sort_index()

# %%
ver2014=grupo1.loc['2014']
ver2015=grupo1.loc['2015']
ver2016=grupo1.loc['2016']
ver2017=grupo1.loc['2017']
ver2018=grupo1.loc['2018']
ver2019=grupo1.loc['2019']

# %%
inv2014=grupo2.loc['2014']
inv2015=grupo2.loc['2015']
inv2016=grupo2.loc['2016']
inv2017=grupo2.loc['2017']
inv2018=grupo2.loc['2018']
inv2019=grupo2.loc['2019']

# %%
KTeΔt2014=pd.concat([ver2014,inv2014])
KTeΔt2014=KTeΔt2014.sort_index()

# %%
KTeΔt2015=pd.concat([ver2015,inv2015])
KTeΔt2015=KTeΔt2015.sort_index()

# %%
KTeΔt2016=pd.concat([ver2016,inv2016])
KTeΔt2016=KTeΔt2016.sort_index()

# %%
KTeΔt2017=pd.concat([ver2017,inv2017])
KTeΔt2017=KTeΔt2017.sort_index()

# %%
KTeΔt2018=pd.concat([ver2018,inv2018])
KTeΔt2018=KTeΔt2018.sort_index()

# %%
KTeΔt2019=pd.concat([ver2019,inv2019])
KTeΔt2019=KTeΔt2019.sort_index()

# %%
KTeΔt=pd.concat([KTeΔt2014,KTeΔt2015,KTeΔt2016,KTeΔt2017,KTeΔt2018,KTeΔt2019])
KTeΔt.shape
# Out:
# (2078, 4)

# %%
Hs.shape
# Out:
# (2191, 3)

# %%
Hs=Hs.loc[Hs.index.isin(KTeΔt.index)]

# %%
plt.plot(KTeΔt.Δt)

# %%
def KTBC(Δt,A,B,C):
    return A*(1-np.exp(-B*Δt**C))

# %%
grupo1
# Out:
#            Unnamed: 0        KT    Δt grupos
# Unnamed: 0
# 2014-01-01 2014-01-01  0.694885   4.3      C
# 2014-01-02 2014-01-02  0.650535   5.2      C
# 2014-01-03 2014-01-03  0.677482   4.7      C
# 2014-01-04 2014-01-04  0.494963   6.0      B
# 2014-01-05 2014-01-05  0.475678   6.0      B
# 2014-01-06 2014-01-06  0.548233   5.7      B
# 2014-01-07 2014-01-07  0.341513   3.7      A
# 2014-01-08 2014-01-08  0.650903   6.5      C
# 2014-01-09 2014-01-09  0.586358   6.5      B
# 2014-01-10 2014-01-10  0.584685   5.0      B
# 2014-01-11 2014-01-11  0.642389   6.2      C
# 2014-01-12 2014-01-12  0.695101   5.1      C
# 2014-01-13 2014-01-13  0.505048   5.7      B
# 2014-01-14 2014-01-14  0.503992   6.5      B
# 2014-01-15 2014-01-15  0.574299   4.7      B
# 2014-01-16 2014-01-16  0.672965   5.3      C
# 2014-01-17 2014-01-17  0.658560   4.4      C
# 2014-01-18 2014-01-18  0.638952   4.1      C
# 2014-01-19 2014-01-19  0.592666   4.6      B
# 2014-01-20 2014-01-20  0.607381   4.2      C
# ...

# %%
g = [0.75,0.7,2.4]

# %matplotlib inline

n1= len(grupo1.KT)
y1= np.empty(n1)

n2= len(grupo2.KT)
y2= np.empty(n2)


for i in range (n1):
    y1[i]=KTBC(grupo1.KT[i],g[0],g[1],g[2])

for i in range (n2):
    y2[i]=KTBC(grupo2.KT[i],g[0],g[1],g[2])   

plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.scatter(grupo2.Δt,y2,color='y')

plt.show()

# %%
from scipy.optimize import curve_fit
c1,cov1 = curve_fit(KTBC,grupo1.Δt.values,grupo1.KT.values,g)
c2,cov2 = curve_fit(KTBC,grupo2.Δt.values,grupo2.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(grupo1.Δt[i],c1[0],c1[1],c1[2])
    
for i in range (n2):
    y2[i]=KTBC(grupo2.Δt[i],c2[0],c2[1],c2[2])
    
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.scatter(grupo2.Δt,y2,color='y')
plt.show()
# Out:
# <ipython-input-21-2da2e0ee181f>:2: RuntimeWarning: divide by zero encountered in power
#   return A*(1-np.exp(-B*Δt**C))

# %%
grupo1.corr()
# Out:
#           KT        Δt
# KT  1.000000  0.066689
# Δt  0.066689  1.000000

# %%
grupo2.corr()
# Out:
#           KT        Δt
# KT  1.000000  0.586118
# Δt  0.586118  1.000000

# %%
c2
# Out:
# array([0.69105723, 0.14383033, 1.42486632])

# %%
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.2)
#plt.scatter(grupo2.Δt,grupo2.KT,color='b',alpha=0.2)
plt.scatter(grupo1.Δt,y1,color='r')
#plt.scatter(grupo2.Δt,y2,color='b')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(grupo1.KT,y1))
# Out:
# R^2:  0.17937872375340402

# %%
plt.scatter(grupo1.Δt.loc['2014'],grupo1.KT.loc['2014'],color='r',alpha=0.3)
plt.scatter(grupo1.Δt.loc['2015'],grupo1.KT.loc['2015'],color='g',alpha=0.3)
plt.scatter(grupo1.Δt.loc['2016'],grupo1.KT.loc['2016'],color='b',alpha=0.3)
plt.scatter(grupo1.Δt.loc['2017'],grupo1.KT.loc['2017'],color='y',alpha=0.3)
plt.scatter(grupo1.Δt.loc['2018'],grupo1.KT.loc['2018'],color='orange',alpha=0.3)
plt.scatter(grupo1.Δt.loc['2019'],grupo1.KT.loc['2019'],color='c',alpha=0.3)
plt.title('Verão')
plt.show()

# %%
plt.scatter(grupo2.Δt.loc['2014'],grupo2.KT.loc['2014'],color='r',alpha=0.35)
plt.scatter(grupo2.Δt.loc['2015'],grupo2.KT.loc['2015'],color='g',alpha=0.35)
plt.scatter(grupo2.Δt.loc['2016'],grupo2.KT.loc['2016'],color='b',alpha=0.35)
plt.scatter(grupo2.Δt.loc['2017'],grupo2.KT.loc['2017'],color='y',alpha=0.35)
plt.scatter(grupo2.Δt.loc['2018'],grupo2.KT.loc['2018'],color='orange',alpha=0.35)
plt.scatter(grupo2.Δt.loc['2019'],grupo2.KT.loc['2019'],color='black',alpha=0.35)
plt.legend(['2014','2015','2016','2017','2018','2019'])
plt.title('Distribuição dos dados no inverno')
plt.xlabel('Amplitude térmica diária (Δt) ')
plt.ylabel('Coeficiente de transmissividade (KT) ')
plt.show()

# %%
def KTBC(Δt,A,B,C):
    return A*(1-np.exp(-B*Δt**C))


g = [0.75,0.7,2.4]

# %%
KTeΔt=KTeΔt.drop(pd.to_datetime('2017-07-05'))

# %%
Hs=Hs.loc[Hs.index.isin(KTeΔt.index)]

# %%
n1= len(KTeΔt.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,KTeΔt.Δt.values,KTeΔt.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(KTeΔt.Δt[i],c[0],c[1],c[2])
    
plt.scatter(KTeΔt.Δt.loc['2014'],KTeΔt.KT.loc['2014'],color='r',alpha=0.40,marker='1')
plt.scatter(KTeΔt.Δt.loc['2015'],KTeΔt.KT.loc['2015'],color='g',alpha=0.35,marker='1')
plt.scatter(KTeΔt.Δt.loc['2016'],KTeΔt.KT.loc['2016'],color='b',alpha=0.30,marker='1')
plt.scatter(KTeΔt.Δt.loc['2017'],KTeΔt.KT.loc['2017'],color='y',alpha=0.25,marker='1')
plt.scatter(KTeΔt.Δt.loc['2018'],KTeΔt.KT.loc['2018'],color='orange',alpha=0.30,marker='1')
plt.scatter(KTeΔt.Δt.loc['2019'],KTeΔt.KT.loc['2019'],color='cyan',alpha=0.30, marker='1')
plt.legend(['2014','2015','2016','2017','2018','2019'])
plt.title('Curva de Distribuição dos Dados')
plt.xlabel('Amplitude Térmica Diária (Δt) ')
plt.ylabel('Coeficiente de Transmissividade (KT) ')
plt.scatter(KTeΔt.Δt,y1,color='red',marker='.')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4fee22784657> in <module>
# ----> 1 n1= len(KTeΔt.KT)
#       2 y1= np.empty(n1)
#       3
#       4 from scipy.optimize import curve_fit
#       5 c,cov = curve_fit(KTBC,KTeΔt.Δt.values,KTeΔt.KT.values,g)
#
# NameError: name 'KTeΔt' is not defined

# %%
y1
# Out:
# array([0.60109018, 0.60627019, 0.60611352, ..., 0.60109018, 0.6037701 ,
#        0.57737271])

# %%
y1
# Out:
# array([0.60109018, 0.60627019, 0.60611352, ..., 0.60109018, 0.6037701 ,
#        0.57737271])

# %%
print('Razão entre Ho e H')
# Out:
# Razão entre Ho e H

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(KTeΔt.KT,y1))
# Out:
# R^2:  0.24060479248889644

# %%
Hs.H.shape
# Out:
# (2077,)

# %%
y1*Hs.Ho
# Out:
# Unnamed: 0
# 2014-01-01    2.285524e+01
# 2014-01-02    2.305975e+01
# 2014-01-03    2.306173e+01
# 2014-01-04    2.307601e+01
# 2014-01-05    2.308469e+01
# 2014-01-06    2.309371e+01
# 2014-01-07    1.957174e+01
# 2014-01-08    2.311269e+01
# 2014-01-09    2.312262e+01
# 2014-01-10    2.313269e+01
# 2014-01-11    2.314325e+01
# 2014-01-12    2.315388e+01
# 2014-01-13    2.316475e+01
# 2014-01-14    2.317577e+01
# 2014-01-15    2.318094e+01
# 2014-01-16    2.319822e+01
# 2014-01-17    2.311389e+01
# 2014-01-18    2.255155e+01
# 2014-01-19    2.321570e+01
# 2014-01-20    2.286524e+01
# 2014-01-21    2.325534e+01
# 2014-01-22    2.325004e+01
# 2014-01-23    2.327822e+01
# 2014-01-24    2.290993e+01
# 2014-01-25    2.330052e+01
# 2014-01-26    2.331143e+01
# 2014-01-27    2.332212e+01
# 2014-01-28    2.323636e+01
# 2014-01-29    2.334278e+01
# 2014-01-30    3.568517e+00
# 2014-01-31    2.336221e+01
# 2014-02-01    2.332893e+01
# 2014-02-02    2.338005e+01
# 2014-02-03    2.338853e+01
# ...

# %%
plt.plot(y1*Hs.Ho)
plt.plot(Hs.H)
correlation_matrix = np.corrcoef(Hs.H,y1*Hs.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 0.35414010642676746

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error((y1*Hs.Ho), (Hs.H), multioutput='raw_values')
# Out:
# array([3.28354058])

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error((y1*Hs.Ho), (Hs.H), squared=False)
rmse
# Out:
# 4.3365090181680594

# %%
n1= len(grupo1.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,grupo1.Δt.values,grupo1.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(grupo1.Δt[i],c[0],c[1],c[2])
    
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.show()

# %%
print('R^2: ', r2_score(grupo1.KT,y1))
# Out:
# R^2:  0.17937872375340402

# %%
Hs2=Hs.loc[Hs.index.isin(grupo1.index)]

# %%
plt.plot(y1*Hs2.Ho)
plt.plot(Hs2.H)
correlation_matrix = np.corrcoef(Hs2.H,y1*Hs2.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 0.19608812207823578

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y1*Hs2.Ho, Hs2.H, multioutput='raw_values')
# Out:
# array([2.95403481])

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y1*Hs2.Ho, Hs2.H, squared=False)
rmse
# Out:
# 4.082948045459308

# %%
grupo2=grupo2.drop(pd.to_datetime('2017-07-05'))

# %%
Hs3=Hs.loc[Hs.index.isin(grupo2.index)]

# %%
n1= len(grupo2.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,grupo2.Δt.values,grupo2.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(grupo2.Δt[i],c[0],c[1],c[2])
    
plt.scatter(grupo2.Δt,grupo2.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,y1,color='g')
plt.show()

# %%
print('R^2: ', r2_score(grupo2.KT,y1))
# Out:
# R^2:  0.3625805583842764

# %%
plt.plot(y1*Hs3.Ho)
plt.plot(Hs3.H)
correlation_matrix = np.corrcoef(Hs3.H,y1*Hs3.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 0.3666475038409902

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y1*Hs3.Ho, Hs3.H, multioutput='raw_values')
# Out:
# array([3.49931084])

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y1*Hs3.Ho,Hs3.H, squared=False)
rmse
# Out:
# 4.381969933520904

# %%
n1= len(inv2015.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,inv2015.Δt.values,inv2015.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(inv2015.Δt[i],c[0],c[1],c[2])
    
plt.scatter(inv2015.Δt,inv2015.KT,color='r',alpha=0.3)
plt.scatter(inv2015.Δt,y1,color='g')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(inv2015.KT,y1))
# Out:
# R^2:  0.21067652913439638

# %%
n1= len(ver2016.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,ver2016.Δt.values,ver2016.KT.values,g)

y1=KTBC(ver2016.Δt,c[0],c[1],c[2])
    
plt.scatter(ver2016.Δt,ver2016.KT,color='r',alpha=0.3)
plt.scatter(ver2016.Δt,y1,color='g')
plt.show()

# %%
print('R^2: ', r2_score(ver2016.KT,y1))
# Out:
# R^2:  0.29105786394073097

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(tudo2016.KT, y1, multioutput='raw_values')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-e7202ccbcb31> in <module>
#       1 from sklearn.metrics import mean_absolute_error
# ----> 2 mean_absolute_error(tudo2016.KT, y1, multioutput='raw_values')
#
# NameError: name 'tudo2016' is not defined

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(tudo2016.KT, y1, squared=False)
rmse

# %%
n1= len(ver2016.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,ver2016.Δt.values,ver2016.KT.values,g)

y1=KTBC(ver2016.Δt,c[0],c[1],c[2])
    
plt.scatter(ver2016.Δt,ver2016.KT,color='r',alpha=0.3)
plt.scatter(ver2016.Δt,y1,color='g')
plt.show()

# %%
print('R^2: ', r2_score(ver2016.KT,y1))

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ver2016.KT, y1, multioutput='raw_values')

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(ver2016.KT, y1, squared=False)
rmse

# %%
n1= len(inv2016.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,inv2016.Δt.values,inv2016.KT.values,g)

y1=KTBC(inv2016.Δt,c[0],c[1],c[2])
    
plt.scatter(inv2016.Δt,inv2016.KT,color='r',alpha=0.3)
plt.scatter(inv2016.Δt,y1,color='g')
plt.show()

# %%
print('R^2: ', r2_score(inv2016.KT,y1))

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(inv2016.KT, y1, multioutput='raw_values')

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(inv2016.KT, y1, squared=False)
rmse

# %%
residuals = inv2016.KT - KTBC(inv2016.Δt, *c)

# %%
ss_res = np.sum(residuals**2)

# %%
ss_tot = np.sum((inv2016.KT-np.mean(inv2016.KT))**2)

# %%
r_squared = 1 - (ss_res / ss_tot)

# %%
r_squared

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(ver2016.KT, y1, squared=False)
rms

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(ver2016.KT, y1, multioutput='raw_values')

# %%
n1= len(inv2017.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,inv2017.Δt.values,inv2017.KT.values,g)

y1=KTBC(inv2017.Δt,c[0],c[1],c[2])
    
plt.scatter(inv2017.Δt,inv2017.KT,color='r',alpha=0.3)
plt.scatter(inv2017.Δt,y1,color='g')
plt.legend(['Dados','Predição'])
plt.title('Método de predição')
plt.xlabel('Amplitude térmica diária (Δt) ')
plt.ylabel('Coeficiente de transmissividade (KT) ')
plt.show()

# %%
print('R^2: ', r2_score(inv2016.KT,y1))

# %%
from sklearn.metrics import mean_squared_error

rms = mean_squared_error(inv2016.KT, y1, squared=False)
rms

# %%
mean_absolute_error(inv2016.KT, y1, multioutput='raw_values')

# %%
#Não esquecer de rodar antes a verão (ou inverno de acordo com a dataframe)
y=y1

# %%
x=ver2016.KT

# %%
import math
(((sum(x*y))-((sum(x)*sum(y))/len(x)))/math.sqrt((sum(x**2)-((sum(x))**2/len(x)))*((sum(y**2)-(sum(y)**2)/len(x)))))**2

# %%
correlation_matrix = np.corrcoef(ver2016.KT,y1)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(y1.sort_values(),ver2016.KT.sort_values()))

# %%
n1= len(ver2017.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,ver2017.Δt.values,ver2017.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(ver2017.Δt[i],c[0],c[1],c[2])
    
plt.scatter(ver2017.Δt,ver2017.KT,color='r',alpha=0.3)
plt.scatter(ver2017.Δt,y1,color='g')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(ver2017.KT,y1))

# %%
n1= len(ver2018.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,ver2018.Δt.values,ver2018.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(ver2018.Δt[i],c[0],c[1],c[2])
    
plt.scatter(ver2018.Δt,ver2018.KT,color='r',alpha=0.3)
plt.scatter(ver2018.Δt,y1,color='g')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(ver2018.KT,y1))

# %%
n1= len(ver2019.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTBC,ver2019.Δt.values,ver2019.KT.values,g)

for i in range (n1):
    y1[i]=KTBC(ver2019.Δt[i],c[0],c[1],c[2])
    
plt.scatter(ver2019.Δt,ver2019.KT,color='r',alpha=0.3)
plt.scatter(ver2019.Δt,y1,color='g')
plt.show()

# %%
from sklearn.metrics import r2_score
print('R^2: ', r2_score(ver2019.KT,y1))

# %% [markdown]
# # Hargreaves:

# %%
def KTH(Δt,A):
    return A*Δt**(0.5)


g = [0.70]

# %%
n1= len(KTeΔt.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTH,KTeΔt.Δt.values,KTeΔt.KT.values,g)

for i in range (n1):
    y1[i]=KTH(KTeΔt.Δt[i],c[0])
    
plt.scatter(KTeΔt.Δt,KTeΔt.KT,color='r',alpha=0.3)
plt.scatter(KTeΔt.Δt,y1,color='g')
plt.show()

# %%
plt.plot(y1*Hs.Ho)
plt.plot(Hs.H)
correlation_matrix = np.corrcoef(Hs.H,y1*Hs.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 0.17885221424388859

# %%
plt.scatter(Hs.H,y1*Hs.Ho)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error((y1*Hs.Ho), (Hs.H), multioutput='raw_values')
# Out:
# array([3.87363077])

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error((y1*Hs.Ho), (Hs.H), squared=False)
rmse
# Out:
# 4.904288119458319

# %%
n1= len(grupo1.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTH,grupo1.Δt.values,grupo1.KT.values,g)

for i in range (n1):
    y1[i]=KTH(grupo1.Δt[i],c[0])
    
plt.scatter(grupo1.Δt,grupo1.KT,color='r',alpha=0.3)
plt.scatter(grupo1.Δt,y1,color='g')
plt.show()

# %%
Hs2=Hs.loc[Hs.index.isin(grupo1.index)]

# %%
plt.plot(y1*Hs2.Ho)
plt.plot(Hs2.H)
correlation_matrix = np.corrcoef(Hs2.H,y1*Hs2.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y1*Hs2.Ho, Hs2.H, multioutput='raw_values')

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y1*Hs2.Ho, Hs2.H, squared=False)
rmse

# %%
Hs3=Hs.loc[Hs.index.isin(grupo2.index)]

# %%
n1= len(grupo2.KT)
y1= np.empty(n1)

from scipy.optimize import curve_fit
c,cov = curve_fit(KTH,grupo2.Δt.values,grupo2.KT.values,g)

for i in range (n1):
    y1[i]=KTH(grupo2.Δt[i],c[0])
    
plt.scatter(grupo2.Δt,grupo2.KT,color='r',alpha=0.3)
plt.scatter(grupo2.Δt,y1,color='g')
plt.show()

# %%
plt.plot(y1*Hs3.Ho)
plt.plot(Hs3.H)
correlation_matrix = np.corrcoef(Hs3.H,y1*Hs3.Ho)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y1*Hs3.Ho, Hs3.H, multioutput='raw_values')

# %%
from sklearn.metrics import mean_squared_error

rmse = mean_squared_error(y1*Hs3.Ho,Hs3.H, squared=False)
rmse

# %%
plt.scatter(dff.dT.loc['2014'],dff.KT.loc['2014'],color='r',alpha=0.40)
plt.scatter(dff.dT.loc['2015'],dff.KT.loc['2015'],color='g',alpha=0.35)
plt.scatter(dff.dT.loc['2016'],dff.KT.loc['2016'],color='b',alpha=0.30)
plt.scatter(dff.dT.loc['2017'],dff.KT.loc['2017'],color='y',alpha=0.25)
plt.scatter(dff.dT.loc['2018'],dff.KT.loc['2018'],color='orange',alpha=0.30)
plt.scatter(dff.dT.loc['2019'],dff.KT.loc['2019'],color='cyan',alpha=0.30,)
plt.legend(['2014','2015','2016','2017','2018','2019'])
plt.title('Curva de estimação do modelo de Goodin',fontname='calibri')
plt.xlabel('ΔT/Ho',fontname='calibri')
plt.ylabel('Coeficiente de Transmissividade (KT) ',fontname='calibri')
plt.scatter(dff.dT,yGoodin,color='red',marker='.')
plt.show()

# %%
import seaborn as sns

tabela_erros = tabela_erros.reindex(['Goodin','BC','Harg','Chen','Anand'])
sns.set_palette('mako')
sns.set_context(font_scale=12,rc={"font.size":12,"axes.labelsize":12})
sns.set_style("white")
plot= sns.barplot(x=tabela_erros.index,y='NSE',data=tabela_erros)
plt.xlabel("Modelos",fontname="Calibri")
plt.ylabel("NSE",fontname="Calibri")
plt.show(plot)

# %%
sns.set_context(font_scale=12,rc={"font.size":12,"axes.labelsize":12})
sns.set_style("white")
plot= sns.barplot(x=tabela_erros.index,y='RMSE',data=tabela_erros)
plt.xlabel("Modelos",fontname="Calibri", fontsize=12)    
plt.ylabel("RMSE",fontname="Calibri")
plt.show(plot)

# %%
tabela_erros = tabela_erros.reindex(['Goodin','BC','Harg','Chen','Anand'])
sns.set_context(font_scale=12,rc={"font.size":12,"axes.labelsize":12})
sns.set_style("white")
plot= sns.barplot(x=tabela_erros.index,y='MAE',data=tabela_erros)
plt.xlabel("Modelos",fontname="Calibri")
plt.ylabel("MAE",fontname="Calibri") 
plt.show(plot)

# %%
tabela_erros = tabela_erros.reindex(['Goodin','BC','Harg','Chen','Anand'])
sns.set_context(font_scale=12,rc={"font.size":12,"axes.labelsize":12})
sns.set_style("white")
plot= sns.barplot(x=tabela_erros.index,y='r2',data=tabela_erros)
plt.xlabel("Modelos",fontname="Calibri")
plt.ylabel("r ²",fontname="Calibri") 
plt.show(plot)
